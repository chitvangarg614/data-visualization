# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
df1= pd.read_csv(r'C:\Users\chitv\Desktop\OnePercent\CSV Files\DIGITAL_MARKETING_PLATFORM_APP_GOOGLE.csv')
df2= pd.read_csv(r'C:\Users\chitv\Desktop\OnePercent\CSV Files\DIGITAL_MARKETING_APP_DATE_GOOGLE.csv')
df3= pd.read_csv(r'C:\Users\chitv\Desktop\OnePercent\CSV Files\DIGITAL_MARKETING_PLATFORM_APP_GOOGLE.csv')

# %%
df1.head(10)
# Out:
#             APP  FACEBOOK  INSTAGRAM  TWITTER  QUORA  LINKEDIN  REDDIT  \
# 0    C Compiler       497        137      139     79        65     706
# 1    C Tutorial       496        153      127     86        36     338
# 2   C# Compiler       226         95      846     10        73     135
# 3   C# Tutorial       349         86      200     11        55     340
# 4  C++ Compiler       248        129      338     23        68     114
# 5  C++ Tutorial       429        131      469     63        49     772
# 6   Calculator+       615         63      122     46        25     249
# 7     Calendar+       521        149      158     16        29      85
# 8     Compiler+       502        125      181     78        26     190
# 9  CSS Tutorial       189        141       99     16        23     114
#
#    SNAPCHAT  YOUTUBE  TIKTOK  EMAIL  OTHER
# 0        52       13       0      9     99
# 1        41       32       0      8    105
# 2        24       25       0      6     43
# ...

# %%
data= df1.drop('APP', axis=1)

# %%
data.FACEBOOK.dtype
# Out:
# dtype('int64')

# %%
data= df1.drop("APP", axis=1)

# %%
sns.heatmap(data)

# %%
df1.groupby('APP').plot(kind='bar')
# Out:
# C:\Users\chitv\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# APP
# C Compiler             AxesSubplot(0.125,0.125;0.775x0.755)
# C Tutorial             AxesSubplot(0.125,0.125;0.775x0.755)
# C# Compiler            AxesSubplot(0.125,0.125;0.775x0.755)
# C# Tutorial            AxesSubplot(0.125,0.125;0.775x0.755)
# C++ Compiler           AxesSubplot(0.125,0.125;0.775x0.755)
# C++ Tutorial           AxesSubplot(0.125,0.125;0.775x0.755)
# CSS Tutorial           AxesSubplot(0.125,0.125;0.775x0.755)
# Calculator+            AxesSubplot(0.125,0.125;0.775x0.755)
# Calendar+              AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %%
df2.head()
# Out:
#          DATE  C_COMPILER  C_TUTORIAL  CSHARP_COMPILER  CSHARP_TUTORIAL  \
# 0  2021-05-28          20           1                2                0
# 1  2021-05-29          16          40                0                0
# 2  2021-05-30           6          25                0                0
# 3  2021-05-31           4          20                0                0
# 4  2021-06-01           8          10                1                0
#
#    CPLUSPLUS_COMPILER  CPLUSPLUS_TUTORIAL  CALCULATORPLUS  CALENDARPLUS  \
# 0                   2                   0               1             3
# 1                   0                   5               0            28
# 2                   0                   1               0             2
# 3                   0                  29               2             2
# 4                   6                   0              12             1
#
#    COMPILERPLUS  ...  PYTHON_TUTORIAL  RUBY_COMPILER  RUBY_TUTORIAL  \
# ...
